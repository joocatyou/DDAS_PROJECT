# %% [markdown]
# #### Local MYSQL Server

# %%
from get.get import *
from calculate.calculate import *
from visualize.visualize import *
from db.db import *
# Out:
# 2026-04-03 16:27:46.285 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
# Get data building data
df_grid, grid_bd_points = get_latest_grid_data()
dfs1 = get_dfs1()

# Get pop/density data
dfs2 = get_dfs2(df_grid)

# Set score
weight_dic = {'broadcast': 0.100,
             'electricity':0.242,
             'factory':0.057,
             'hospital':0.030,
             'infra':0.079,
             'prison':0.011,
             'public':0.116,
             'science':0.013,
             'telecommunication':0.153,
             'transportation':0.081,
             'water':0.055,
             'frequency':0.025}
set_score(dfs1, weight_dic)

# Parameters
RANGE_KM = 1.5

# Rank calculation
rank_dic, max_radar_num = calc_rank(dfs1, df_grid, RANGE_KM, radar_num=50, polygon_coords=grid_bd_points)

df_population = dfs2['population']
df_area_density = dfs2['area_density']

df_final = get_df_final(rank_dic, df_grid, df_population, df_area_density, RANGE_KM)

upload_result(df_final)
# Out:
# ------------------------------
# 1순위
# 위치 : [ 37.558841 126.995048]
# 점수 : 0.8579999999999989
# 남은 시설물 : 0개
# ------------------------------
# 최대 radar 개수: 1
# 저장 완료: case13

# %%
# Icon config
ICON_MAP = {
    "broadcast":         folium.Icon(color="orange",     icon="broadcast-tower",   prefix="fa"),
    "electricity":       folium.Icon(color="green",      icon="bolt",              prefix="fa"),
    "factory":           folium.Icon(color="blue",       icon="industry",          prefix="fa"),
    "hospital":          folium.Icon(color="red",        icon="hospital",          prefix="fa"),
    "infra":             folium.Icon(color="darkblue",   icon="cogs",              prefix="fa"),
    "prison":            folium.Icon(color="black",      icon="university",        prefix="fa"),
    "public":            folium.Icon(color="cadetblue",  icon="building",          prefix="fa"),
    "science":           folium.Icon(color="pink",       icon="flask",             prefix="fa"),
    "telecommunication": folium.Icon(color="beige",      icon="satellite-dish",    prefix="fa"),
    "transportation":    folium.Icon(color="darkgreen",  icon="train",             prefix="fa"),
    "water":             folium.Icon(color="lightblue",  icon="tint",              prefix="fa"),
    "frequency":         folium.Icon(color="darkred",    icon="signal",            prefix="fa"),
}
visualize(df_grid, dfs1, rank_dic, RANGE_KM, ICON_MAP,
              show_rank=None, polygon_coords=grid_bd_points,
              df_final=df_final)
# Out:
# 저장 완료: map.html

# %% [markdown]
# #### SQL SERVER

# %%
from get.get_server import *
from get.get import *
from calculate.calculate import *
from visualize.visualize import *
from db.db_server import *
# Out:
# 2026-04-03 17:11:30.471 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-03 17:11:30.472 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
dfs1 = get_dfs1_server()

df_grid, grid_bd_points =  get_latest_grid_data()
dfs2 = get_dfs2_server(df_grid)

# Set score
weight_dic = {'broadcast': 0.100,
             'electricity':0.242,
             'factory':0.057,
             'hospital':0.030,
             'infra':0.079,
             'prison':0.011,
             'public':0.116,
             'science':0.013,
             'telecommunication':0.153,
             'transportation':0.081,
             'water':0.055,
             'frequency':0.025}
set_score(dfs1, weight_dic)

# Parameters
RANGE_KM = 1.5

# Rank calculation
rank_dic, max_radar_num = calc_rank(dfs1, df_grid, RANGE_KM, radar_num=50, polygon_coords=grid_bd_points)

df_population = dfs2['population']
df_area_density = dfs2['area_density']

df_final = get_df_final(rank_dic, df_grid, df_population, df_area_density, RANGE_KM)

upload_result_server(df_final)
# Out:
# 2026-04-03 17:11:44.823 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-04-03 17:11:44.825 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# d:\workspaces\00_Project\crawlProject\project\get\get_server.py:47: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   with engine.connect() as conn:
# d:\workspaces\00_Project\crawlProject\project\get\get_server.py:129: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   inspector = inspect(engine)
# --- CSV 데이터 확인 및 적재 시작 ---
# 'broadcast' 테이블은 이미 존재하여 건너뜀.
# 'electricity' 테이블은 이미 존재하여 건너뜀.
# 'factory' 테이블은 이미 존재하여 건너뜀.
# 'frequency' 테이블은 이미 존재하여 건너뜀.
# 'hospital' 테이블은 이미 존재하여 건너뜀.
# 'infra' 테이블은 이미 존재하여 건너뜀.
# 'population_raw' 테이블은 이미 존재하여 건너뜀.
# 'prison' 테이블은 이미 존재하여 건너뜀.
# 'public' 테이블은 이미 존재하여 건너뜀.
# 'science' 테이블은 이미 존재하여 건너뜀.
# 'telecommunication' 테이블은 이미 존재하여 건너뜀.
# 'transportation' 테이블은 이미 존재하여 건너뜀.
# 'water' 테이블은 이미 존재하여 건너뜀.
#
# --- GeoJSON 데이터 확인 및 적재 시작 ---
# 'density' 테이블은 이미 존재하여 건너뜀.
# d:\workspaces\00_Project\crawlProject\project\get\get_server.py:209: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   inspector = inspect(engine)
# c:\Users\user2\miniconda3\envs\jsenv\Lib\site-packages\pandas\io\sql.py:1648: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
# ------------------------------
# 1순위
# 위치 : [ 37.528625 126.985386]
# 점수 : 0.395
# 남은 시설물 : 0개
# ------------------------------
# 최대 radar 개수: 1
# 'result' 데이터베이스가 이미 존재한다.
# d:\workspaces\00_Project\crawlProject\project\db\db_server.py:31: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   with autocommit_engine.connect() as conn:
# d:\workspaces\00_Project\crawlProject\project\db\db_server.py:45: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   with engine_result.connect() as conn:
# [case4] 테이블에 저장 성공!
